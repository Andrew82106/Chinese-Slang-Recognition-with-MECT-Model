# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs

# 生成样本数据
n_samples = 100
n_features = 256
X, _ = make_blobs(n_samples=n_samples, centers=3, n_features=n_features, random_state=42)
print(X.shape, type(X))
# 对数据进行标准化
X = StandardScaler().fit_transform(X)

# 执行DBSCAN聚类分析
dbscan = DBSCAN(eps=25, min_samples=5)
clusters = dbscan.fit_predict(X)

# 可视化聚类结果
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
clusters, len(set(clusters))
# Out:
# (100, 256) <class 'numpy.ndarray'>
# (array([0, 1, 1, 1, 1, 1, 2, 2, 0, 2, 1, 2, 2, 0, 0, 1, 1, 0, 2, 2, 2, 0,
#         1, 0, 0, 0, 0, 0, 0, 1, 1, 1, 2, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 1,
#         2, 2, 0, 1, 0, 2, 0, 0, 2, 0, 2, 0, 2, 1, 1, 2, 0, 2, 2, 2, 1, 0,
#         2, 1, 1, 2, 2, 1, 1, 1, 2, 0, 1, 0, 2, 2, 2, 1, 2, 1, 2, 2, 0, 2,
#         0, 0, 2, 1, 1, 0, 1, 0, 0, 0, 1, 1]),
#  3)
